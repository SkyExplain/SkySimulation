# %%
import healpy as hp
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import os
import matplotlib.pyplot as plt
from healpy import read_map
tf.keras.backend.clear_session() #clear any previous models

data_directory = "/mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/CMBFeatureNet/data/"
os.chdir(data_directory)
os.environ['CUDA_VISIBLE_DEVICES'] = '-1' #disable GPU
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  #suppress TF warnings
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /mnt/lustre/scratch/nlsas/home/csic/eoy/ioj/CMBFeatureNet/data

# %%
from astropy.io import fits
def read_map(file_path):
    """
    Reads a Healpy map from a FITS file and flattens the data.
    """
    
    with fits.open(file_path) as hdul:
        hdul.info()
        if len(hdul) > 1 and hasattr(hdul[1], 'columns'):
            print(hdul[1].columns)
        return np.concatenate(hdul[1].data['T'])

# %%
#Read the data
path_lcdm = "./simulated_maps/lcdm/"
map_temp_data = read_map(path_lcdm + 'cmb_map_0.fits')

#Visualize the map
nside = hp.npix2nside(len(map_temp_data))
#nside = 64
print(f"NSIDE: {nside}")

#Plot
hp.mollview(map_temp_data, title="Temperature Map", unit="Intensity")
plt.show()
# Out:
# Filename: ./simulated_maps/lcdm/cmb_map_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# NSIDE: 128

# %%
def read_all_maps(path_lcdm, path_feature, n_maps=100):
    maps = []
    labels = []
    
    #LCDM maps
    for i in range(n_maps):
        map_lcdm = read_map(f"{path_lcdm}cmb_map_{i}.fits")
        maps.append(map_lcdm)
        labels.append(0)  #lcdm
    
    #Feature maps
    for i in range(n_maps):
        map_feature = read_map(f"{path_feature}cmb_map_feature_{i}.fits")
        maps.append(map_feature)
        labels.append(1)  #feature
    
    maps = np.array(maps).astype(np.float32)[..., None]  #Add channel dimension
    labels = np.array(labels).astype(np.int32)
    #print(labels)
    return maps, labels

# %%
path_feature = "./simulated_maps/feature/"
x_raw, y_raw = read_all_maps(path_lcdm, path_feature, n_maps=100) #0: lcdm, 1:feature
# Out:
# Filename: ./simulated_maps/lcdm/cmb_map_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_28.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_29.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_30.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_31.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_32.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_33.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_34.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_35.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_36.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_37.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_38.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_39.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_40.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_41.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_42.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_43.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_44.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_45.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_46.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_47.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_48.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_49.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_50.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_51.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_52.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_53.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_54.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_55.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_56.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_57.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_58.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_59.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_60.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_61.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_62.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_63.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_64.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_65.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_66.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_67.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_68.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_69.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_70.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_71.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_72.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_73.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_74.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_75.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_76.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_77.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_78.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_79.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_80.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_81.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_82.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_83.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_84.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_85.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_86.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_87.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_88.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_89.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_90.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_91.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_92.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_93.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_94.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_95.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_96.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_97.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_98.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/lcdm/cmb_map_99.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_15.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_18.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_20.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_21.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_22.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_23.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_24.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_26.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_28.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_29.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_30.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_31.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_32.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_33.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_34.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_35.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_36.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_37.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_38.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_39.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_40.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_41.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_42.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_43.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_44.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_45.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_46.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_47.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_48.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_49.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_50.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_51.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_52.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_53.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_54.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_55.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_56.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_57.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_58.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_59.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_60.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_61.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_62.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_63.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_64.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_65.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_66.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_67.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_68.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_69.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_70.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_71.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_72.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_73.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_74.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_75.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_76.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_77.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_78.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_79.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_80.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_81.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_82.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_83.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_84.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_85.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_86.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_87.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_88.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_89.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_90.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_91.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_92.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_93.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_94.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_95.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_96.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_97.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_98.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )
# Filename: ./simulated_maps/feature/cmb_map_feature_99.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  xtension      1 BinTableHDU     18   192R x 1C   [1024D]
# ColDefs(
#     name = 'T'; format = '1024D'
# )

# %%
maps_model = np.atleast_2d(x_raw)
print("Shape of maps_model:", maps_model.shape)
# Out:
# Shape of maps_model: (200, 196608, 1)

# %%
#Normalize:
X = (maps_model - np.mean(maps_model, axis=1, keepdims=True)) / np.std(maps_model, axis=1, keepdims=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_raw, test_size=0.2, random_state=42)

# %%
#======== Define Model ========
model = models.Sequential([
    layers.Input(shape=(X.shape[1],)),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(84, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary(110)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                                   ┃ Output Shape                        ┃             Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                                  │ (None, 512)                         │         100,663,808 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ dropout (Dropout)                              │ (None, 512)                         │                   0 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ dense_1 (Dense)                                │ (None, 256)                         │             131,328 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ dropout_1 (Dropout)                            │ (None, 256)                         │                   0 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ dense_2 (Dense)                                │ (None, 1)                           │                 257 │
# └────────────────────────────────────────────────┴─────────────────────────────────────┴─────────────────────┘
#  Total params: 100,795,393 (384.50 MB)
#  Trainable params: 100,795,393 (384.50 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4906 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4542 - loss: 0.6933 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5531 - loss: 0.6930 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5156 - loss: 0.6930 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5094 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5000 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4802 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4927 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5552 - loss: 0.6930 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4760 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5146 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4604 - loss: 0.6933 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4979 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5271 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5042 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4979 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4948 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4771 - loss: 0.6933 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4740 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4729 - loss: 0.6933 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5458 - loss: 0.6930 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5083 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5188 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5052 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5219 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5198 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4635 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4927 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4885 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5083 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4844 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5573 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5281 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4802 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5021 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5177 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4948 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5323 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4437 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5167 - loss: 0.6930 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4927 - loss: 0.6933 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4594 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4854 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - accuracy: 0.4823 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4250 - loss: 0.6933 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4906 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5167 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5094 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4344 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4938 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4875 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4854 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5052 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4927 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4885 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4417 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5177 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5510 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4708 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5198 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5635 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4635 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.3917 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4885 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5365 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5094 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4781 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4479 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4917 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5260 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5135 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4698 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4417 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5312 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4833 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4917 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5292 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4990 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5510 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4635 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4885 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4781 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4354 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4812 - loss: 0.6931 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.4177 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.5646 - loss: 0.6931 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4156 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5281 - loss: 0.6932 - val_accuracy: 0.5312 - val_loss: 0.6931
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4635 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4615 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4781 - loss: 0.6931 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4750 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6931
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4760 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4948 - loss: 0.6931 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4875 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4865 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4646 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5021 - loss: 0.6931 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5448 - loss: 0.6932 - val_accuracy: 0.4688 - val_loss: 0.6932
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4958 - loss: 0.6931 - val_accuracy: 0.4688 - val_loss: 0.6932

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5375 - loss: 0.6931
# Test accuracy: 0.5250

# %%
#Function for the probability of classification as LCDM 
def normFeat(p):
  if 0<p<0.5:
    rr=1-p
  else:
    rr=p
  return rr

#Function for the probability of classification as Feature 
def normLCDM(p):
  if 0<p<0.5:
    rr=p
  else:
    rr=1-p
  return rr

# %%
theory = ['LCDM','FT']

true_model=[]
pred_model=[]
prob_pred_MoG=[]
prob_pred_LCDM=[]
for i in range(len(X_test)):
  X_test_tf = tf.convert_to_tensor([X_test[i]])
  predictions = model.predict(X_test_tf)
  true_model.append(round(y_test[i]))
  pred_model.append(round(predictions[0][0]))
  prob_pred_MoG.append(round(100*normFeat(predictions[0][0]),3))
  prob_pred_LCDM.append(round(100*normLCDM(predictions[0][0]),3))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="validation")
plt.grid()
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"], label="training")
plt.plot(history.history["val_loss"], label="validation")
plt.grid()
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
#-----------------------------------------------------------------------------------------------------------
#Performance: correct & incorrect  predictions
#-----------------------------------------------------------------------------------------------------------
true_LCDM = []
true_MoG = []
false_LCDM = []
false_MoG = []

for pred, true in zip(pred_model, true_model):
    if pred==0 and true==0:
        true_LCDM.append(1)
    if pred==1 and true==1:
        true_MoG.append(1)
    if pred==0 and true==1:
        false_LCDM.append(1)
    if pred==1 and true==0:
        false_MoG.append(1)
lenghts=[len(true_LCDM),len(true_MoG),len(false_LCDM),len(false_MoG)]

print('     ','LCDM','FT')
print('True ',len(true_LCDM)/sum(lenghts),len(true_MoG)/sum(lenghts))
print('False',len(false_LCDM)/sum(lenghts),len(false_MoG)/sum(lenghts))
print('--------------')
print("Correct prediction: ",(len(true_LCDM)+len(true_MoG))/sum(lenghts))
print("Wrong prediction  : ",(len(false_LCDM)+len(false_MoG))/sum(lenghts))
# Out:
#       LCDM MoG
# True  0.525 0.0
# False 0.475 0.0
# --------------
# Correct prediction:  0.525
# Wrong prediction  :  0.475
